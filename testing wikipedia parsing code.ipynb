# %%
import os
import codecs
import csv
import bz2
import time
import json

# %%
dump_path = save_path = r"C:\Users\smrut\Downloads"
filename = os.path.join(dump_path, "latest-all.json.bz2")
file_identification = os.path.join(save_path, "WD_identification_item.csv")
file_wikibase_entityid  = os.path.join(save_path, "WD_wikibase_entityid.csv")
file_quantity = os.path.join(save_path, "WD_quantity.csv")
file_globecoordinate = os.path.join(save_path, "WD_globecoordinate.csv")
file_time = os.path.join(save_path, "WD_time.csv")

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


def ent_values(ent):
    wd_type = ent["type"]
    wd_item = ent["id"]
    
    if ent["labels"].get("en", "not found") == "not found":
        wd_label = ""
    else:
        wd_label = ent["labels"]["en"]["value"]
    
    if ent["descriptions"].get("en", "not found") == "not found":
        wd_desc = ""
    else:
        wd_desc = ent["descriptions"]["en"]["value"]
    
    if ent["sitelinks"].get("enwiki", "not found") == "not found":
        wd_title = ""
    else:
        wd_title = ent["sitelinks"]["enwiki"]["title"]
        
    return([wd_type, wd_item, wd_label, wd_desc, wd_title])


def concat_claims(claims):
    for rel_id, rel_claims in claims.items():
        for claim in rel_claims:
            yield claim

# %%
i = 0

start_time = time.time()

with codecs.open(file_identification, "w", "utf-8") as op_identification,codecs.open(file_wikibase_entityid, "w", "utf-8") as op_wikibase_entityid,codecs.open(file_quantity, "w", "utf-8") as op_quantity,codecs.open(file_globecoordinate, "w", "utf-8") as op_globecoordinate,codecs.open(file_time, "w", "utf-8") as op_time:
    
    opw_identification = csv.writer(op_identification, quoting=csv.QUOTE_MINIMAL)
    opw_identification.writerow(["WD_Type", "WD_WikiData_Item",
                       "WD_Label", "WD_Description", "WD_Title"])
    
    opw_wikibase_entityid = csv.writer(op_wikibase_entityid, quoting=csv.QUOTE_MINIMAL)
    opw_wikibase_entityid.writerow(["WD_Subject","WD_Predicate","WD_Object"])    
    
    opw_quantity = csv.writer(op_quantity, quoting=csv.QUOTE_MINIMAL)
    opw_quantity.writerow(["WD_Subject","WD_Predicate","WD_Object","WD_Units"])    
    
    opw_globecoordinate = csv.writer(op_globecoordinate, quoting=csv.QUOTE_MINIMAL)
    opw_globecoordinate.writerow(["WD_Subject","WD_Predicate","WD_Object","WD_Precision"])
    
    opw_time = csv.writer(op_time, quoting=csv.QUOTE_MINIMAL)
    opw_time.writerow(["WD_Subject","WD_Predicate","WD_Object","WD_Precision"])
    
    
    with bz2.BZ2File(filename, "rb") as f:
        for line in f:
            line = line.decode('utf_8',errors="ignore")
            if i<=0:
                pass
            elif i>=1000000000:
                break
            elif line in ("[\n", "]\n"):
                pass
            else:
                ent = json.loads(line.rstrip('\n,'))
                
                if ent["type"] != "item":
                    continue
                    
                opw_identification.writerow(ent_values(ent))
                
                claims = concat_claims(ent["claims"])
                e1 = ent["id"]
            
                for claim in claims:
                    mainsnak = claim["mainsnak"]
                    rel = mainsnak["property"]
                    snak_datatype = mainsnak["datatype"]
                    
                    if mainsnak['snaktype'] == "value":
                        snak_value = mainsnak["datavalue"]["value"]
                        
                        if snak_datatype in ("wikibase-item", "wikibase-property"):
                            opw_wikibase_entityid.writerow([e1, rel, snak_value["id"]])
                            
                        elif snak_datatype == "quantity":
                            e2 = (snak_value["amount"],snak_value["unit"].strip(r"http://www.wikidata.org/entity/"))
                            opw_quantity.writerow([e1, rel, e2[0],e2[1]])
                            
                        elif snak_datatype == "globe-coordinate":
                            e2 = ((snak_value["latitude"],snak_value["longitude"]),snak_value["precision"])
                            opw_globecoordinate.writerow([e1, rel, e2[0], e2[1]])
                            
                        elif snak_datatype == "time":
                            e2 = (snak_value["time"],snak_value["precision"])
                            opw_time.writerow([e1, rel, e2[0],e2[1]])
                            
                        else:
                            pass            
                   
                
            if (i % 100000) == 0:
                    print("Total item processed: {:,}".format(i))
            i = i + 1

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
# Out:
# Total item processed: 0
# Total item processed: 100,000
# Total item processed: 200,000
# Total item processed: 300,000
# Total item processed: 400,000
# Total item processed: 500,000
# Total item processed: 600,000
# Total item processed: 700,000
# Total item processed: 800,000
# Total item processed: 900,000
# Total item processed: 1,000,000
# Total item processed: 1,100,000
# Total item processed: 1,200,000
# Total item processed: 1,300,000
# Total item processed: 1,400,000
# Total item processed: 1,500,000
# Total item processed: 1,600,000
# Total item processed: 1,700,000
# Total item processed: 1,800,000
# Total item processed: 1,900,000
# Total item processed: 2,000,000
# Total item processed: 2,100,000
# Total item processed: 2,200,000
# Total item processed: 2,300,000
# Total item processed: 2,400,000
# Total item processed: 2,500,000
# Total item processed: 2,600,000
# Total item processed: 2,700,000
# Total item processed: 2,800,000
# Total item processed: 2,900,000
# Total item processed: 3,000,000
# Total item processed: 3,100,000
# Total item processed: 3,200,000
# Total item processed: 3,300,000
# Total item processed: 3,400,000
# Total item processed: 3,500,000
# Total item processed: 3,600,000
# Total item processed: 3,700,000
# Total item processed: 3,800,000
# Total item processed: 3,900,000
# Total item processed: 4,000,000
# Total item processed: 4,100,000
# Total item processed: 4,200,000
# Total item processed: 4,300,000
# Total item processed: 4,400,000
# Total item processed: 4,500,000
# Total item processed: 4,600,000
# Total item processed: 4,700,000
# Total item processed: 4,800,000
# Total item processed: 4,900,000
# Total item processed: 5,000,000
# Total item processed: 5,100,000
# Total item processed: 5,200,000
# Total item processed: 5,300,000
# Total item processed: 5,400,000
# Total item processed: 5,500,000
# Total item processed: 5,600,000
# Total item processed: 5,700,000
# Total item processed: 5,800,000
# Total item processed: 5,900,000
# Total item processed: 6,000,000
# Total item processed: 6,100,000
# Total item processed: 6,200,000
# Total item processed: 6,300,000
# Total item processed: 6,400,000
# Total item processed: 6,500,000
# Total item processed: 6,600,000
# Total item processed: 6,700,000
# Total item processed: 6,800,000
# Total item processed: 6,900,000
# Total item processed: 7,000,000
# Total item processed: 7,100,000
# Total item processed: 7,200,000
# Total item processed: 7,300,000
# Total item processed: 7,400,000
# Total item processed: 7,500,000
# Total item processed: 7,600,000
# Total item processed: 7,700,000
# Total item processed: 7,800,000
# Total item processed: 7,900,000
# Total item processed: 8,000,000
# Total item processed: 8,100,000
# Total item processed: 8,200,000
# Total item processed: 8,300,000
# Total item processed: 8,400,000
# Total item processed: 8,500,000
# Total item processed: 8,600,000
# Total item processed: 8,700,000
# Total item processed: 8,800,000
# Total item processed: 8,900,000
# Total item processed: 9,000,000
# Total item processed: 9,100,000
# Total item processed: 9,200,000
# Total item processed: 9,300,000
# Total item processed: 9,400,000
# Total item processed: 9,500,000
# Total item processed: 9,600,000
# Total item processed: 9,700,000
# Total item processed: 9,800,000
# Total item processed: 9,900,000
# Total item processed: 10,000,000
# Total item processed: 10,100,000
# Total item processed: 10,200,000
# Total item processed: 10,300,000
# Total item processed: 10,400,000
# Total item processed: 10,500,000
# Total item processed: 10,600,000
# Total item processed: 10,700,000
# Total item processed: 10,800,000
# Total item processed: 10,900,000
# Total item processed: 11,000,000
# Total item processed: 11,100,000
# Total item processed: 11,200,000
# Total item processed: 11,300,000
# Total item processed: 11,400,000
# Total item processed: 11,500,000
# Total item processed: 11,600,000
# Total item processed: 11,700,000
# Total item processed: 11,800,000
# Total item processed: 11,900,000
# Total item processed: 12,000,000
# Total item processed: 12,100,000
# Total item processed: 12,200,000
# Total item processed: 12,300,000
# Total item processed: 12,400,000
# Total item processed: 12,500,000
# Total item processed: 12,600,000
# Total item processed: 12,700,000
# Total item processed: 12,800,000
# Total item processed: 12,900,000
# Total item processed: 13,000,000
# Total item processed: 13,100,000
# Total item processed: 13,200,000
# Total item processed: 13,300,000
# Total item processed: 13,400,000
# Total item processed: 13,500,000
# Total item processed: 13,600,000
# Total item processed: 13,700,000
# Total item processed: 13,800,000
# Total item processed: 13,900,000
# Total item processed: 14,000,000
# Total item processed: 14,100,000
# Total item processed: 14,200,000
# Total item processed: 14,300,000
# Total item processed: 14,400,000
# Total item processed: 14,500,000
# Total item processed: 14,600,000
# Total item processed: 14,700,000
# Total item processed: 14,800,000
# Total item processed: 14,900,000
# Total item processed: 15,000,000
# Total item processed: 15,100,000
# Total item processed: 15,200,000
# Total item processed: 15,300,000
# Total item processed: 15,400,000
# Total item processed: 15,500,000
# Total item processed: 15,600,000
# Total item processed: 15,700,000
# Total item processed: 15,800,000
# Total item processed: 15,900,000
# Total item processed: 16,000,000
# Total item processed: 16,100,000
# Total item processed: 16,200,000
# Total item processed: 16,300,000
# Total item processed: 16,400,000
# Total item processed: 16,500,000
# Total item processed: 16,600,000
# Total item processed: 16,700,000
# Total item processed: 16,800,000
# Total item processed: 16,900,000
# Total item processed: 17,000,000
# Total item processed: 17,100,000
# Total item processed: 17,200,000
# Total item processed: 17,300,000
